# %% [markdown]
# # Script to create composites of SST gradient based on ENSO phase

# %%
import numpy as np
import matplotlib.pyplot as plt
from cartopy import crs as ccrs
import xarray as xr

from grad_funcs import get_gs_coords_alltime,get_total_gradient

# %%
## months to perform analysis, for full year set analysis_months = range(1,13)

analysis_months = [2]


dslink = '/Users/noahrosenberg/Downloads/era5_shf_1deg.nc'#era5_sst_1940_2022_1deg.nc'

ds = xr.load_dataset(f'{dslink}',engine='netcdf4')
ds = ds.where(ds.time.dt.month.isin(analysis_months))
# Out:
# /Users/noahrosenberg/miniconda3/lib/python3.11/site-packages/xarray/core/accessor_dt.py:72: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   values_as_series = pd.Series(values.ravel(), copy=False)

# %%
path = "/Users/noahrosenberg/Documents/GitHub/GulfStream_TBI/cesm_2deg_pi/*.nc"
sst = xr.open_mfdataset(path)

sst = sst.TS

sst = sst[:840]

sst.load()
# Out:
# <xarray.DataArray 'TS' (time: 840, lat: 96, lon: 144)>
# array([[[240.52739, 240.62549, 240.36934, ..., 240.49648, 240.49886,
#          240.53003],
#         [240.85289, 241.52798, 241.0935 , ..., 241.44606, 241.60342,
#          241.2167 ],
#         [242.00084, 242.69055, 241.93398, ..., 242.67117, 243.56985,
#          243.00171],
#         ...,
#         [244.85002, 245.07233, 245.2009 , ..., 244.08794, 244.37645,
#          244.61069],
#         [243.50198, 243.54642, 243.55276, ..., 243.15677, 243.28358,
#          243.40015],
#         [242.36613, 242.35608, 242.34792, ..., 242.31876, 242.34795,
#          242.36809]],
#
#        [[231.89247, 231.92245, 231.8079 , ..., 231.88022, 231.88075,
#          231.89653],
#         [231.40648, 231.85841, 231.43262, ..., 232.07971, 232.15842,
#          231.70409],
#         [232.35252, 232.82231, 232.39737, ..., 232.82587, 233.25665,
#          232.96402],
# ...
#         [243.35725, 243.4992 , 243.66841, ..., 242.68039, 242.89522,
# ...

# %%
sst = ds.sshf

# %%
## get dates from Nino script and dataarray into same format

nino_dates = np.load('ninodates_model.npy',allow_pickle=True)

nino_months = nino_dates.astype('datetime64[M]')

year0 = sst.time.dt.year.min()
year0 = int(year0)

nino_indices = nino_months.astype('int')+(1970-year0)*12

sst_month_indices = (sst.time.dt.year-year0)*12 + sst.time.dt.month

sst_nino = sst.where(sst_month_indices.isin(nino_indices),drop=True)
sst_nino = sst_nino

# %%
fig,ax = plt.subplots(figsize=(10,10),subplot_kw={'projection':ccrs.PlateCarree()})
im = ax.pcolormesh(sst_nino.lon,sst_nino.lat,sst_nino.mean('time'),transform=ccrs.PlateCarree())
#im2 = ax.contour(sst.lon,sst.lat,tot_grad.mean('time'),levels=(1,288),c='r')

ax.set_extent((-80,-40,20,75))
plt.colorbar(im,ax=ax)
ax.coastlines()

# %%
nina_dates = np.load('ninadates_model.npy',allow_pickle=True)

nina_months = nina_dates.astype('datetime64[M]')

year0 = sst.time.dt.year.min()
year0 = int(year0)

nina_indices = nina_months.astype('int')+(1970-year0)*12

sst_month_indices = (sst.time.dt.year-year0)*12 + sst.time.dt.month

sst_nina = sst.where(sst_month_indices.isin(nina_indices),drop=True)

# %%
from matplotlib import colors

# plot difference in gradients between 2 composites

nina_grad = get_total_gradient(sst_nina,1,latname='lat',lonname='lon').mean('time')
nino_grad = get_total_gradient(sst,1,latname='lat',lonname='lon').mean('time')

fig,ax = plt.subplots(figsize=(5,5),subplot_kw={'projection':ccrs.PlateCarree()})
im = ax.pcolormesh(sst_nina.lon,sst_nina.lat,
                   nino_grad-nina_grad,
                   transform=ccrs.PlateCarree(),
                   #vmin=0,vmax=0.03,
                   cmap="RdBu_r",norm=colors.CenteredNorm(0,0.0005))#,cmap='RdBu_r')
#im2 = ax.contour(sst.longitude,sst.latitude,sst.mean('time'),levels=20,colors='k',linewidths=0.5)

#im2 = ax.contour(sst.lon,sst.lat,tot_grad.mean('time'),levels=(1,288),c='r')

ax.set_extent((-80,-40,20,75))
plt.colorbar(im,ax=ax)
ax.coastlines()

# %%
import haversine as hs
from haversine import Unit

da = sst
n_roll = 1
latname = 'lat'
lonname = 'lon'

# Get Longitude
lats  = da[latname]
lats0 = np.squeeze(np.dstack((lats,np.zeros(len(lats)))))
lats1 = np.squeeze(np.dstack((lats,np.ones(len(lats)))))

# Distances
xdist = hs.haversine_vector(lats0,lats1,Unit.KILOMETERS)
ydist = 111*(lats[1]-lats[0]) # take distance between latitudes as 111 km

# Compute Meridional
y1    = da.roll({latname:n_roll},roll_coords=False)
y2    = da.roll({latname:-1*n_roll},roll_coords=False)
ygrad = (y1 - y2)/(2 * n_roll * ydist)
#ygrad1 = (da.roll({'lat':n_roll}) - da.roll({'lat':-1*n_roll}))/(2 * n_roll * ydist)

# Compute Zonal
x1  = da.roll({lonname:n_roll},roll_coords=False)
x2  = da.roll({lonname:-1*n_roll},roll_coords=False)
xgrad = (x1 - x2)/(2 * n_roll * xdist[None,:,None])
#xgrad1 = (da.roll({'lon':n_roll}) - da.roll({'lon':-1*n_roll}))/(2 * n_roll * xdist[None,:,None])

# Get total gradient
grad_tot = (xgrad**2 + ygrad**2)**0.5

# %%
grad_tot
# Out:
# <xarray.DataArray (time: 840, lat: 96, lon: 144)>
# array([[[7.01012718e+12, 1.16066012e+13, 1.90122807e+13, ...,
#          2.03827068e+12, 2.46407763e+12, 2.09541845e+12],
#         [4.24790446e-02, 3.30902709e-02, 6.69377763e-02, ...,
#          7.49674172e-03, 3.20355770e-02, 1.02242550e-01],
#         [2.18005967e-02, 5.23667956e-03, 5.82514695e-02, ...,
#          9.53805009e-02, 2.41110396e-02, 1.07205530e-01],
#         ...,
#         [3.16823651e-02, 2.44239290e-02, 1.90795022e-02, ...,
#          4.80277099e-02, 3.56049504e-02, 3.23676860e-02],
#         [2.07509556e-02, 9.45500102e-03, 7.08874345e-03, ...,
#          3.52977009e-02, 3.34491322e-02, 3.01772390e-02],
#         [8.81868621e+11, 1.33793028e+12, 1.06899957e+12, ...,
#          3.99810323e+12, 3.62272078e+12, 1.33568919e+12]],
#
#        [[1.90380532e+12, 6.21005832e+12, 7.89199581e+12, ...,
#          4.13480967e+11, 1.19786221e+12, 8.60578273e+11],
# ...
